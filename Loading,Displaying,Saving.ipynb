# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulwasaeee/modern-computer-vision-course/blob/main/Loading%2CDisplaying%2CSaving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/logo_MCV_W.png)
#
#
# # **Getting Started**
#
# Welcome to your first OpenCV Lesson. Here we'll learn to:
# 1. Import the OpenCV Model in Python
# 2. Load Images
# 3. Display Images
# 4. Save Images
# 5. Getting the Image Dimensions

# %%
# This is how we import OpenCV, we can't use OpenCV's functions without first doing this
import cv2

# %%
# Let's see what version we're running
cv2.__version__
# Out:
# '4.12.0'

# %% [markdown]
# ### **Dowloading Images**
#
# If using Google Colab, we'll have to **upload our image**.
#
# Colab is a Jupyther Notebook environment that runs on the **cloud** using Google's servers. As such, any file we wish to use needs to be uploaded to their servers.

# %%
# !gdown "https://drive.google.com/uc?id=1O2uCujErifjvK1ziRGssaQO9khI15g6q"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1O2uCujErifjvK1ziRGssaQO9khI15g6q
# From (redirected): https://drive.google.com/uc?id=1O2uCujErifjvK1ziRGssaQO9khI15g6q&confirm=t&uuid=5eda83d8-a590-46b3-8fcb-a0e73efda3af
# To: /content/images.zip
# 100% 29.6M/29.6M [00:00<00:00, 80.2MB/s]

# %%
# !unzip -qq images.zip

# %%
# Download and unzip our images- not working
# !cp "/content/drive/MyDrive/Modern Computer Vision/OpenCV/images.zip" .
# !unzip -qq images.zip
# Out:
# cp: cannot stat '/content/drive/MyDrive/Modern Computer Vision/OpenCV/images.zip': No such file or directory
# unzip:  cannot find or open images.zip, images.zip.zip or images.zip.ZIP.

# %% [markdown]
# ### **Loading Images**

# %%
# Load an image using 'imread' specifying the path to image
image = cv2.imread('images/castara.jpeg')

# %%
from matplotlib import pyplot as plt
plt.imshow (image)

# %% [markdown]
# ### **Displaying Images**

# %%
#Show the image with matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Let's create a simple function to make displaying our images simpler and easier

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# Let's test it  out
imshow("Displaying Our First Image", image)

# %% [markdown]
# ### **Saving Images**

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
# Or save it as a PNG (Portable Network Graphics) which is a Lossless bitmap image format
cv2.imwrite(' output.png', image)
# Out:
# True

# %% [markdown]
# ### **Displaying Image Dimensions**
#
# Remember Images are arrays:
#
# ![](https://raw.githubusercontent.com/rajeevratan84/ModernComputerVision/main/array.png?token=ADLZD2HNEL33JAKTYRM3B5C7WMIV4)

# %% [markdown]
# We need to use numpy to perform this operation. Don't worry, numpy will become one of your best friends if you're learning a Data Science and Computer Vision.

# %%
# Import numpy
import numpy as np

print(image.shape)
# Out:
# (1280, 960, 3)

# %%
# To access a dimension, simply index it by using 0, 1 or 2.
image.shape[0]
# Out:
# 1280

# %% [markdown]
# You can see the first dimension is the height and it's 960 pixels
#
# The second dimension is the width which is 1280 pixels.
#
# We can print them out nicely like this:

# %%
print(f'Height of Image: {int(image.shape[0])} pixels ')
print(f'Width of Image: {int(image.shape[1])} pixels')
print(f'Depth of Image: {int(image.shape[2])} colors components ')
# Out:
# Height of Image: 1280 pixels
# Width of Image: 960 pixels
# Depth of Image: 3 colors components
