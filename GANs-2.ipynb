# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulwasaeee/modern-computer-vision-course/blob/main/GANs-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/logo_MCV_W.png)
#
# # **Generative Adversarial Networks (GANs) in PyTorch - Deep Convolutional GANs or DCGAN with MNIST**
#
# ---
#
# In this lesson, we will learn how to use PyTorch to create a simple DCGAN using the MNIST dataset.

# %% [markdown]
# ## **1. Setting up our data and modules**

# %%
import torch
from torch import nn

import math
import matplotlib.pyplot as plt
import torchvision
import torchvision.transforms as transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
torch.manual_seed(42)
# Out:
# cuda

# %% [markdown]
# ## **2. Fetch our MNIST Dataset using torchvision and Create our transforms and Data Loader**

# %%
batch_size = 32

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_set = torchvision.datasets.MNIST(root=".", train=True, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 15.3MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 404kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.77MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.87MB/s]

# %%
len(train_loader)
# Out:
# 1875

# %% [markdown]
# ### **Now let's plot some of our original (real) data**

# %%
samples, labels = next(iter(train_loader))

for i in range(32):
    ax = plt.subplot(4, 8, i + 1)
    plt.imshow(samples[i].reshape(28, 28), cmap="gray")
    plt.xticks([])
    plt.yticks([])

# %%
from torchvision.utils import make_grid
grid= make_grid(samples[:9],nrow=3)
plt.imshow(grid.permute(1,2,0))
plt.axis('off')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# (np.float64(-0.5), np.float64(91.5), np.float64(91.5), np.float64(-0.5))

# %% [markdown]
# ## **4. Define our Discriminator Model**
#
# Our Descriminator receives the 28x28 image generated by our Generator and outputs a probability score of it belonging to the original dataset or not.

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            # We don't use Conv layers here but we vectorize our inputs
            nn.Linear(784, 2048),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(2048, 1024),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 1),
        )

    def forward(self, x):
      x = torch.flatten(x, start_dim=1)
      output = self.model(x)
      return output

# We instantiate our mode and send it to the GPU
discriminator = Discriminator().to(device=device)

# %% [markdown]
# ## **5. Define our Generator Model**

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(100, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 784),
            nn.Tanh(), # We use the Tanh() activation fucntion so that our outputs lie between -1 and 1
        )

    def forward(self, x):
      output = self.model(x)
      output = output.reshape(x.size(0), 1, 28, 28)
      return output


# We instantiate our mode and send it to the GPU
generator = Generator().to(device=device)

# %% [markdown]
# ## **Set our training parameters**

# %%
# Set our learning rate, epochs
lr = 0.0001
epochs = 20
lossfn = nn.BCEWithLogitsLoss()

optimizerD = torch.optim.Adam(discriminator.parameters(), lr=1e-4)
optimizerG = torch.optim.Adam(generator.parameters(), lr=2e-4)

# %%
for epoch in range(epochs):
    for n, (samples, labels) in enumerate(train_loader):
        # Get data for training the discriminator
        realsamples = samples.to(device=device)
        reallabels = torch.ones((batch_size, 1)).to(device=device)
        latentsamples = torch.randn((batch_size, 100)).to(device=device)
        generatedsamples = generator(latentsamples)
        generatedlabels = torch.zeros((batch_size, 1)).to(device=device)
        allsamples = torch.cat((realsamples, generatedsamples))
        alllabels = torch.cat((reallabels, generatedlabels))

        # Training the discriminator
        discriminator.zero_grad()
        outputD1 = discriminator(allsamples)
        lossD = lossfn(outputD1, alllabels)
        lossD.backward()
        optimizerD.step()

        # Data for training the generator
        latentsamples = torch.randn((batch_size, 100)).to(device=device)

        # Training the generator
        generator.zero_grad()
        generatedsamples = generator(latentsamples)
        outputD2 = discriminator(generatedsamples)
        lossG = lossfn(outputD2, reallabels)
        lossG.backward()
        optimizerG.step()

        # Show loss
        if n == len(train_loader) - 1:
            print(f"Epoch: {epoch} Descrimianted Loss: {lossD}")
            print(f"Epoch: {epoch} Generator Loss: {lossG}")
# Out:
# Epoch: 0 Descrimianted Loss: 0.19532614946365356
# Epoch: 0 Generator Loss: 3.824225902557373
# Epoch: 1 Descrimianted Loss: 0.06559363007545471
# Epoch: 1 Generator Loss: 4.608908176422119
# Epoch: 2 Descrimianted Loss: 0.08515724539756775
# Epoch: 2 Generator Loss: 4.965500354766846
# Epoch: 3 Descrimianted Loss: 0.17453216016292572
# Epoch: 3 Generator Loss: 2.9611268043518066
# Epoch: 4 Descrimianted Loss: 0.14660216867923737
# Epoch: 4 Generator Loss: 3.5668787956237793
# Epoch: 5 Descrimianted Loss: 0.1519777476787567
# Epoch: 5 Generator Loss: 2.371734619140625
# Epoch: 6 Descrimianted Loss: 0.2306923270225525
# Epoch: 6 Generator Loss: 3.1713333129882812
# Epoch: 7 Descrimianted Loss: 0.34433287382125854
# Epoch: 7 Generator Loss: 2.308579444885254
# Epoch: 8 Descrimianted Loss: 0.385933518409729
# Epoch: 8 Generator Loss: 1.573940396308899
# Epoch: 9 Descrimianted Loss: 0.2875702977180481
# Epoch: 9 Generator Loss: 1.8608794212341309
# Epoch: 10 Descrimianted Loss: 0.41138240694999695
# Epoch: 10 Generator Loss: 1.5484490394592285
# Epoch: 11 Descrimianted Loss: 0.41683316230773926
# Epoch: 11 Generator Loss: 1.5996758937835693
# Epoch: 12 Descrimianted Loss: 0.5744122266769409
# Epoch: 12 Generator Loss: 1.4994115829467773
# Epoch: 13 Descrimianted Loss: 0.41334840655326843
# Epoch: 13 Generator Loss: 1.1257023811340332
# Epoch: 14 Descrimianted Loss: 0.49795931577682495
# Epoch: 14 Generator Loss: 1.3792344331741333
# Epoch: 15 Descrimianted Loss: 0.44633063673973083
# Epoch: 15 Generator Loss: 1.2328288555145264
# Epoch: 16 Descrimianted Loss: 0.5240288972854614
# Epoch: 16 Generator Loss: 1.0067567825317383
# Epoch: 17 Descrimianted Loss: 0.5238264203071594
# Epoch: 17 Generator Loss: 1.0577523708343506
# Epoch: 18 Descrimianted Loss: 0.4464087188243866
# Epoch: 18 Generator Loss: 1.0623005628585815
# Epoch: 19 Descrimianted Loss: 0.5862680077552795
# Epoch: 19 Generator Loss: 1.1436622142791748

# %% [markdown]
# ## **5. Now let's Inspect our Generated Samples**

# %%
latentsamples = torch.randn(batch_size, 100).to(device=device)
generatedsamples = generator(latentsamples)

# %%
from torchvision.utils import make_grid

# %%
grid= make_grid(generatedsamples).cpu()
plt.imshow(grid.permute(1,2,0))
plt.axis('off')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# (np.float64(-0.5), np.float64(241.5), np.float64(121.5), np.float64(-0.5))
